# %% [markdown]
# # Tentative d'une représentaion heatmap de données aero

# %% [markdown]
# ### carto_aero.xlsx

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb

# %%
df = pd.read_excel("carto_aero.xlsx")
df.columns =  ["x","y","v"]

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
# n = 5000
df2 = df 
# df2 = df.sample(n)
ax = df2.plot.scatter(figsize=(10, 7),x='x',y='y',c='v',
                 grid=False,colormap="viridis")
ax.set_ylabel('échelle');
ax.set_xlabel('x');
ax.set_title("HeatMap de carto_aero");

# %%
df2 = df 

ax = df2.plot.scatter(figsize=(10, 7),x='x',y='y',c='v',xlim=[-50,50],ylim=[-50,50],
                 grid=False,colormap="viridis")
ax.set_ylabel('échelle');
ax.set_xlabel('x');
ax.set_title("HeatMap de carto_aero Zoom 50");

# %% [markdown]
# ### carto_aero v2.xlsx

# %%
df_v2 = pd.read_excel("carto_aerov2.xlsx",sheetname="Sheet1")

# %%
df_v2.columns =  ["x","y","v"]

# %%
df_v2.head()
# Out:
#            x          y         v
# 0 -200.16000  200.16000  0.000000
# 1 -200.16000 -200.16000  0.000000
# 2  200.16000 -200.16000  0.000000
# 3  200.16000  200.16000  0.000000
# 4   -6.65029    2.69879  0.002378

# %%
df2 = df_v2
ax = df2.plot.scatter(figsize=(10, 7),x='x',y='y',c='v',xlim=[-50,50],ylim=[-50,50],
                 grid=False,colormap="viridis")
ax.set_ylabel('échelle');
ax.set_xlabel('x');
ax.set_title("HeatMap de carto_aero 2 Zoom 50");
